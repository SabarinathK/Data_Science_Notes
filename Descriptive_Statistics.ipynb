# %% [markdown]
# # Normal distribution
#
#
# 1) Outiler (wrong data points)
#   - drop
#   - Caping ( median)
#   - trimming(3 std)
#
# 2) Missing value

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = sns.load_dataset("tips")

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
data.describe(include='all')  #numerical only
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
data['tip'].mean()
# Out:
# 2.99827868852459

# %%
data['tip'].std()
# Out:
# 1.3836381890011822

# %%
sns.displot(data=data, x="tip", col="smoker", kde=True)

# %%
sns.boxplot( x="tip",data=data)
# Out:
# <AxesSubplot: xlabel='tip'>

# %%
q1=data['tip'].quantile(0.25)
q3=data['tip'].quantile(0.75)

iqr=q3-q1



lower_range=q1-iqr*1.5
upper_range=q3+iqr*1.5

print(lower_range,upper_range)
# Out:
# -0.34375 5.90625

# %%
data=data[data['tip']<5.90625]

# %%
data
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [235 rows x 7 columns]

# %%
sns.boxplot( x="tip",data=data)
# Out:
# <AxesSubplot: xlabel='tip'>

# %% [markdown]
# # Data Preprocessing

# %%
df = sns.load_dataset("tips")
df.shape
# Out:
# (244, 7)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
df[df.duplicated()]
# Out:
#      total_bill  tip     sex smoker   day   time  size
# 202        13.0  2.0  Female    Yes  Thur  Lunch     2

# %%
df=df.drop_duplicates()
df.shape
# Out:
# (243, 7)

# %%
df.isnull().count()
# Out:
# total_bill    243
# tip           243
# sex           243
# smoker        243
# day           243
# time          243
# size          243
# dtype: int64

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 7 columns]

# %%
y=df['tip']
X=df.drop('tip',axis=1)

# %%
y
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 243, dtype: float64

# %%
X
# Out:
#      total_bill     sex smoker   day    time  size
# 0         16.99  Female     No   Sun  Dinner     2
# 1         10.34    Male     No   Sun  Dinner     3
# 2         21.01    Male     No   Sun  Dinner     3
# 3         23.68    Male     No   Sun  Dinner     2
# 4         24.59  Female     No   Sun  Dinner     4
# ..          ...     ...    ...   ...     ...   ...
# 239       29.03    Male     No   Sat  Dinner     3
# 240       27.18  Female    Yes   Sat  Dinner     2
# 241       22.67    Male    Yes   Sat  Dinner     2
# 242       17.82    Male     No   Sat  Dinner     2
# 243       18.78  Female     No  Thur  Dinner     2
#
# [243 rows x 6 columns]

# %%
for i in X:
    print(i)
    print(X[i].unique())
    print(' ')
# Out:
# total_bill
# [16.99 10.34 21.01 23.68 24.59 25.29  8.77 26.88 15.04 14.78 10.27 35.26
#  15.42 18.43 14.83 21.58 10.33 16.29 16.97 20.65 17.92 20.29 15.77 39.42
#  19.82 17.81 13.37 12.69 21.7  19.65  9.55 18.35 15.06 20.69 17.78 24.06
#  16.31 16.93 18.69 31.27 16.04 17.46 13.94  9.68 30.4  18.29 22.23 32.4
#  28.55 18.04 12.54 10.29 34.81  9.94 25.56 19.49 38.01 26.41 11.24 48.27
#  13.81 11.02 17.59 20.08 16.45  3.07 20.23 15.01 12.02 17.07 26.86 25.28
#  14.73 10.51 27.2  22.76 17.29 19.44 16.66 10.07 32.68 15.98 34.83 13.03
#  18.28 24.71 21.16 28.97 22.49  5.75 16.32 22.75 40.17 27.28 12.03 12.46
#  11.35 15.38 44.3  22.42 20.92 15.36 20.49 25.21 18.24 14.31 14.    7.25
#  38.07 23.95 25.71 17.31 29.93 10.65 12.43 24.08 11.69 13.42 14.26 15.95
#  12.48 29.8   8.52 14.52 11.38 22.82 19.08 20.27 11.17 12.26 18.26  8.51
#  14.15 16.   13.16 17.47 34.3  41.19 27.05 16.43  8.35 18.64 11.87  9.78
#   7.51 14.07 13.13 17.26 24.55 19.77 29.85 48.17 25.   13.39 16.49 21.5
# ...

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [243 rows x 7 columns]

# %%
X.columns
# Out:
# Index(['total_bill', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
X['sex']=X['sex'].replace({'Female':0, 'Male':1})
X['smoker']=X['smoker'].replace({'No':0, 'Yes':1})
X['day']=X['day'].replace({'Sun':0, 'Sat':1, 'Thur':3, 'Fri':4})
X['time']=X['time'].replace({'Dinner':0, 'Lunch':1})

# %%
X
# Out:
#      total_bill sex smoker day time  size
# 0         16.99   0      0   0    0     2
# 1         10.34   1      0   0    0     3
# 2         21.01   1      0   0    0     3
# 3         23.68   1      0   0    0     2
# 4         24.59   0      0   0    0     4
# ..          ...  ..    ...  ..  ...   ...
# 239       29.03   1      0   1    0     3
# 240       27.18   0      1   1    0     2
# 241       22.67   1      1   1    0     2
# 242       17.82   1      0   1    0     2
# 243       18.78   0      0   3    0     2
#
# [243 rows x 6 columns]

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 243
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  243 non-null    float64
#  1   sex         243 non-null    category
#  2   smoker      243 non-null    category
#  3   day         243 non-null    category
#  4   time        243 non-null    category
#  5   size        243 non-null    int64
# dtypes: category(4), float64(1), int64(1)
# memory usage: 7.2 KB

# %%
X['sex']=pd.to_numeric(X['sex'])
X['smoker']=pd.to_numeric(X['smoker'])
X['day']=pd.to_numeric(X['day'])
X['time']=pd.to_numeric(X['time'])

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 243
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  243 non-null    float64
#  1   sex         243 non-null    int64
#  2   smoker      243 non-null    int64
#  3   day         243 non-null    int64
#  4   time        243 non-null    int64
#  5   size        243 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 13.3 KB

# %%
 X.columns
# Out:
# Index(['total_bill', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
for i in X.columns:
    print(i)
    sns.boxplot(X[i])
    plt.show()
# Out:
# total_bill
# sex
# smoker
# day
# time
# size

# %%
X.describe(include='all')
# Out:
#        total_bill         sex      smoker         day        time        size
# count  243.000000  243.000000  243.000000  243.000000  243.000000  243.000000
# mean    19.813868    0.646091    0.378601    1.423868    0.275720    2.572016
# std      8.910071    0.479168    0.486040    1.359602    0.447799    0.952356
# min      3.070000    0.000000    0.000000    0.000000    0.000000    1.000000
# 25%     13.380000    0.000000    0.000000    0.000000    0.000000    2.000000
# 50%     17.810000    1.000000    0.000000    1.000000    0.000000    2.000000
# 75%     24.175000    1.000000    1.000000    3.000000    1.000000    3.000000
# max     50.810000    1.000000    1.000000    4.000000    1.000000    6.000000

# %%
q1=X['total_bill'].quantile(0.25)

q3=X['total_bill'].quantile(0.75)

IQR=q3-q2
print("IQR",IQR)


lower_range=q2-IQR*1.5
Upper_range=q3+IQR*1.5


print('lower_range',lower_range)
print("Upper_range",Upper_range)
# Out:
# IQR 6.364999999999998
# lower_range 8.262500000000001
# Upper_range 33.7225

# %%
x[X['total_bill']>=33.7225]
# Out:
#      total_bill     sex smoker   day    time  size
# 11        35.26  Female     No   Sun  Dinner     4
# 23        39.42    Male     No   Sat  Dinner     4
# 52        34.81  Female     No   Sun  Dinner     4
# 56        38.01    Male    Yes   Sat  Dinner     4
# 59        48.27    Male     No   Sat  Dinner     4
# 85        34.83  Female     No  Thur   Lunch     4
# 95        40.17    Male    Yes   Fri  Dinner     4
# 102       44.30  Female    Yes   Sat  Dinner     3
# 112       38.07    Male     No   Sun  Dinner     3
# 141       34.30    Male     No  Thur   Lunch     6
# 142       41.19    Male     No  Thur   Lunch     5
# 156       48.17    Male     No   Sun  Dinner     6
# 170       50.81    Male    Yes   Sat  Dinner     3
# 179       34.63    Male    Yes   Sun  Dinner     2
# 180       34.65    Male    Yes   Sun  Dinner     4
# 182       45.35    Male    Yes   Sun  Dinner     3
# 184       40.55    Male    Yes   Sun  Dinner     2
# ...

# %%
df=df[df['total_bill']<=33.7225]
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [222 rows x 7 columns]

# %%
for i in x.columns:
    print(i)
    sns.boxplot(x[i])
    plt.show()
# Out:
# total_bill
# sex
# smoker
# day
# time
# size
